# %%
# 📊 Sales Performance Dashboard

## Project Overview

### Business Problem

ABC Retail wants to analyze its sales performance across different regions, customer segments, and product categories. The management team requires an interactive dashboard that provides insights into sales trends, profitability, customer behavior, and regional performance to support better business decisions.

### Objective

The objective of this project is to:

- Clean and validate the dataset.
- Perform Exploratory Data Analysis (EDA).
- Answer business questions using SQL.
- Build an interactive Power BI Dashboard.
- Generate business insights and recommendations.

### Tools Used

- Python
- Pandas
- NumPy
- Matplotlib
- SQL
- Power BI
- Excel

---
# Out:
#   Cell In[1], line 7
#     ABC Retail wants to analyze its sales performance across different regions, customer segments, and product categories. The management team requires an interactive dashboard that provides insights into sales trends, profitability, customer behavior, and regional performance to support better business decisions.
#         ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_excel("../DataSet/Superstore.xls")

print(df.shape)
print(df.columns.tolist())
# Out:
# (10194, 21)
# ['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country/Region', 'City', 'State/Province', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit']

# %%
print("Minimum Order Date :", df["Order Date"].min())
print("Maximum Order Date :", df["Order Date"].max())

print("Minimum Ship Date :", df["Ship Date"].min())
print("Maximum Ship Date :", df["Ship Date"].max())
# Out:
# Minimum Order Date : 2023-01-03 00:00:00
# Maximum Order Date : 2026-12-30 00:00:00
# Minimum Ship Date : 2023-01-07 00:00:00
# Maximum Ship Date : 2027-01-05 00:00:00

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10194 entries, 0 to 10193
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          10194 non-null  int64
#  1   Order ID        10194 non-null  str
#  2   Order Date      10194 non-null  datetime64[us]
#  3   Ship Date       10194 non-null  datetime64[us]
#  4   Ship Mode       10194 non-null  str
#  5   Customer ID     10194 non-null  str
#  6   Customer Name   10194 non-null  str
#  7   Segment         10194 non-null  str
#  8   Country/Region  10194 non-null  str
#  9   City            10194 non-null  str
#  10  State/Province  10194 non-null  str
#  11  Postal Code     10194 non-null  object
#  12  Region          10194 non-null  str
#  13  Product ID      10194 non-null  str
#  14  Category        10194 non-null  str
#  15  Sub-Category    10194 non-null  str
#  16  Product Name    10194 non-null  str
#  17  Sales           10194 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country/Region    0
# City              0
# State/Province    0
# Postal Code       0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe().T
# Out:
#               count                        mean                  min  \
# Row ID      10194.0                      5097.5                  1.0
# Order Date    10194  2025-04-29 11:48:25.002943  2023-01-03 00:00:00
# Ship Date     10194  2025-05-03 10:52:45.626839  2023-01-07 00:00:00
# Sales       10194.0                  228.225854                0.444
# Quantity    10194.0                    3.791838                  1.0
# Discount    10194.0                    0.155385                  0.0
# Profit      10194.0                   28.673417            -6599.978
#
#                             25%                  50%                  75%  \
# Row ID                  2549.25               5097.5              7645.75
# Order Date  2024-05-14 00:00:00  2025-06-25 00:00:00  2026-05-14 00:00:00
# Ship Date   2024-05-19 00:00:00  2025-06-28 00:00:00  2026-05-18 00:00:00
# Sales                     17.22                53.91                209.5
# ...

# %%
# Data Cleaning Summary

## Data Quality Assessment

The dataset was assessed for data quality before analysis.

### Observations

- The dataset contains **10,194 records** and **21 columns**.
- No missing values were found.
- No duplicate records were identified.
- Date columns are correctly recognized as datetime.
- Sales, Profit, Quantity, and Discount have appropriate numeric data types.
- Postal Code is stored as text, which is acceptable because it is an identifier rather than a numerical measure.

### Conclusion

The dataset is clean and suitable for Exploratory Data Analysis (EDA).
